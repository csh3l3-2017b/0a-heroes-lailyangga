# %%
import pandas as pd
df = pd.read_csv("test.csv")
df
# Out:
#            name  movementSpeed  physicalAttack  armor    hp  mana
# 0         Layla            270             118     15  2500   424
# 1       Cyclops            250             107     18  2461   500
# 2      Minotaur            265             123     25  2705     0
# 3         Saber            265             121     17  2475   443
# 4         Roger            235             120     22  2580   450
# 5          Nana            250             110     17  2325   499
# 6          Akai            260             115     24  2769   422
# 7         Alice            240             109     21  2397   493
# 8         Alpha            236             121     20  2646   453
# 9       Alucard            265             118     21  2593     0
# 10        Argus            260             124     21  2628     0
# 11       Aurora            245             105     17  2441   500
# 12      Balmond            265             114     23  2602     0
# ...

# %%
import csv
with open('test.csv') as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    print(readCSV)

# %%
import pandas as pd
data = pd.read_csv('test.csv')
print(data)
# Out:
#            name  movementSpeed  physicalAttack  armor    hp  mana
# 0         Layla            270             118     15  2500   424
# 1       Cyclops            250             107     18  2461   500
# 2      Minotaur            265             123     25  2705     0
# 3         Saber            265             121     17  2475   443
# 4         Roger            235             120     22  2580   450
# 5          Nana            250             110     17  2325   499
# 6          Akai            260             115     24  2769   422
# 7         Alice            240             109     21  2397   493
# 8         Alpha            236             121     20  2646   453
# 9       Alucard            265             118     21  2593     0
# 10        Argus            260             124     21  2628     0
# 11       Aurora            245             105     17  2441   500
# 12      Balmond            265             114     23  2602     0
# ...

# %%
import pandas as pd
data = pd.read_csv('test.csv', delimiter="\t")
print(data)
# Out:
#    name,movementSpeed,physicalAttack,armor,hp,mana
# 0                        Layla,270,118,15,2500,424
# 1                      Cyclops,250,107,18,2461,500
# 2                       Minotaur,265,123,25,2705,0
# 3                        Saber,265,121,17,2475,443
# 4                        Roger,235,120,22,2580,450
# 5                         Nana,250,110,17,2325,499
# 6                         Akai,260,115,24,2769,422
# 7                        Alice,240,109,21,2397,493
# 8                        Alpha,236,121,20,2646,453
# 9                        Alucard,265,118,21,2593,0
# 10                         Argus,260,124,21,2628,0
# 11                      Aurora,245,105,17,2441,500
# 12                       Balmond,265,114,23,2602,0
# 13                        Bane,265,117,23,2625,433
# 14                       Bruno,240,116,17,2402,439
# 15                          Chou,265,121,23,2598,0
# 16                       Clint,248,122,20,2500,450
# ...

# %%
import pandas as pd
data = pd.read_csv('test.csv', delimiter=",")
print(data)
# Out:
#            name  movementSpeed  physicalAttack  armor    hp  mana
# 0         Layla            270             118     15  2500   424
# 1       Cyclops            250             107     18  2461   500
# 2      Minotaur            265             123     25  2705     0
# 3         Saber            265             121     17  2475   443
# 4         Roger            235             120     22  2580   450
# 5          Nana            250             110     17  2325   499
# 6          Akai            260             115     24  2769   422
# 7         Alice            240             109     21  2397   493
# 8         Alpha            236             121     20  2646   453
# 9       Alucard            265             118     21  2593     0
# 10        Argus            260             124     21  2628     0
# 11       Aurora            245             105     17  2441   500
# 12      Balmond            265             114     23  2602     0
# ...

# %%
import pandas as pd
df = pd.read_csv('test.csv', sep=" ", header=None, names=["a", "b", "c"])
print(data)
# Out:
#            name  movementSpeed  physicalAttack  armor    hp  mana
# 0         Layla            270             118     15  2500   424
# 1       Cyclops            250             107     18  2461   500
# 2      Minotaur            265             123     25  2705     0
# 3         Saber            265             121     17  2475   443
# 4         Roger            235             120     22  2580   450
# 5          Nana            250             110     17  2325   499
# 6          Akai            260             115     24  2769   422
# 7         Alice            240             109     21  2397   493
# 8         Alpha            236             121     20  2646   453
# 9       Alucard            265             118     21  2593     0
# 10        Argus            260             124     21  2628     0
# 11       Aurora            245             105     17  2441   500
# 12      Balmond            265             114     23  2602     0
# ...

# %%
def loadtest(filename, trainingSet=[]):
    with open(filename, 'cs') as csvfile:
        lines = csv.reader(csvfile)
        dataset = list(lines)
        for x in range(len(dataset)):
            for y in range(4):
                dataset[x][y] = float(dataset[x][y])
            trainingSet.append(dataset[x])

# %%
import csv
with open('test.csv') as csvfile:
reader = csv.reader(csvfile, delimiter=",")
for row in readCSV:
print(row)
# Out:
#   File "<ipython-input-17-64054fa4f15e>", line 3
#     reader = csv.reader(csvfile, delimiter=",")
#          ^
# IndentationError: expected an indented block

# %%
import csv
 
file = open('test.csv', 'r')
reader = csv.reader(file)
for data in reader:
    print(data)
# Out:
# ['name', 'movementSpeed', 'physicalAttack', 'armor', 'hp', 'mana']
# ['Layla', '270', '118', '15', '2500', '424']
# ['Cyclops', '250', '107', '18', '2461', '500']
# ['Minotaur', '265', '123', '25', '2705', '0']
# ['Saber', '265', '121', '17', '2475', '443']
# ['Roger', '235', '120', '22', '2580', '450']
# ['Nana', '250', '110', '17', '2325', '499']
# ['Akai', '260', '115', '24', '2769', '422']
# ['Alice', '240', '109', '21', '2397', '493']
# ['Alpha', '236', '121', '20', '2646', '453']
# ['Alucard', '265', '118', '21', '2593', '0']
# ['Argus', '260', '124', '21', '2628', '0']
# ['Aurora', '245', '105', '17', '2441', '500']
# ['Balmond', '265', '114', '23', '2602', '0']
# ['Bane', '265', '117', '23', '2625', '433']
# ['Bruno', '240', '116', '17', '2402', '439']
# ['Chou', '265', '121', '23', '2598', '0']
# ['Clint', '248', '122', '20', '2500', '450']
# ['Diggie', '250', '115', '16', '2351', '490']
# ['Estes', '240', '115', '13', '2161', '545']
# ...

# %%
import csv

import csv

getData = []
saveData = []

saveData.insert(0, ['name', 'role'])

with open('test.csv') as filecsv:
	line = csv.reader(filecsv)
	dataset = list(line)

	for x in range(53):
		for y in range (5):
			dataset[x][y] = dataset[x][y]
		getData.append(dataset[x])
		
for index in range(1, len(getData)):
	if int (getData[index][1]) >= 270:
		saveData.append([getData[index][0], 'MARKSMAN'])
	elif int (getData[index][2]) >= 121:
		saveData.append([getData[index][0], 'ASSASSIN'])
	elif int (getData[index][3]) >= 25:
		saveData.append([getData[index][0], 'TANK'])
	if int (getData[index][4]) >= 2580:
		saveData.append([getData[index][0], 'FIGHTER'])
	if int (getData[index][5]) >= 500:
		saveData.append([getData[index][0], 'MAGE'])
	else: 
		saveData.append([getData[index][0], 'SUPPORT'])
		
with open('Prediction.csv', 'w', newline='') as createcsv:
	new = csv.writer(createcsv)
	for x in range(len(saveData)):
		baris.writerow(saveData[x])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-c8e79815ed90> in <module>()
#      34         new = csv.writer(createcsv)
#      35         for x in range(len(saveData)):
# ---> 36                 baris.writerow(saveData[x])
#
# NameError: name 'baris' is not defined

# %%
import csv

getData = []
saveData = []

saveData.insert(0, ['name', 'role'])

with open('test.csv') as filecsv:
	line = csv.reader(filecsv)
	dataset = list(line)

	for x in range(53):
		for y in range (5):
			dataset[x][y] = dataset[x][y]
		getData.append(dataset[x])
		
for index in range(1, len(getData)):
	if int (getData[index][1]) >= 270:
		saveData.append([getData[index][0], 'MARKSMAN'])
	elif int (getData[index][2]) >= 121:
		saveData.append([getData[index][0], 'ASSASSIN'])
	elif int (getData[index][3]) >= 25:
		saveData.append([getData[index][0], 'TANK'])
	if int (getData[index][4]) >= 2580:
		saveData.append([getData[index][0], 'FIGHTER'])
	if int (getData[index][5]) >= 500:
		saveData.append([getData[index][0], 'MAGE'])
	else: 
		saveData.append([getData[index][0], 'SUPPORT'])
		
with open('Prediction.csv', 'w', newline='') as createcsv:
	new = csv.writer(createcsv)
	for x in range(len(saveData)):
		new.writerow(saveData[x])

# %%
#Laily Dwi Anggaraini
#1301178513
#IF 41 GAB02

import csv #memasukkan file csv

getData = [] #inisialisasi awal variable
saveData = []

saveData.insert(0, ['name', 'role']) #menambahkan baris atau nama kolom

with open('test.csv') as filecsv: 
	line = csv.reader(filecsv)  #membuka file csv yang ada pada disk c 
	dataset = list(line)

	for x in range(53):  #perulangan sejumlah data yang akan dicari 
		for y in range (5):
			dataset[x][y] = dataset[x][y]
		getData.append(dataset[x])
	
for index in range(1, len(getData)): #perulangan untuk mengecek satu persatu hero dan mengambil data
	if int (getData[index][1]) >= 270:
		saveData.append([getData[index][0], 'MARKSMAN'])  #mengecek berdasarkan movementSpeed
	elif int (getData[index][2]) >= 121:
		saveData.append([getData[index][0], 'ASSASSIN'])  #mengecek berdasarkan physicalAttack
	elif int (getData[index][3]) >= 25:
		saveData.append([getData[index][0], 'TANK'])      #mengecek berdasarkan armor
	if int (getData[index][4]) >= 2580:
		saveData.append([getData[index][0], 'FIGHTER'])   #mengecek hp
	if int (getData[index][5]) >= 500:
		saveData.append([getData[index][0], 'MAGE'])      #mengecek mana
	else: 
		saveData.append([getData[index][0], 'SUPPORT'])
		
with open('Prediction.csv', 'w', newline='') as createcsv:   #mengcreate file csv berupa hasil prediksi
	new = csv.writer(createcsv)
	for x in range(len(saveData)):
		new.writerow(saveData[x])

# %%
#Laily Dwi Anggaraini
#1301178513
#IF 41 GAB02

import csv #memasukkan file csv

getData = [] #inisialisasi awal variable
saveData = []

saveData.insert(0, ['name', 'role']) #menambahkan baris atau nama kolom

with open('test.csv') as filecsv: 
	line = csv.reader(filecsv)  #membuka file csv yang ada pada disk c 
	dataset = list(line)

	for x in range(53):  #perulangan sejumlah data yang akan dicari 
		for y in range (5):
			dataset[x][y] = dataset[x][y]
		getData.append(dataset[x])
	
for index in range(1, len(getData)): #perulangan untuk mengecek satu persatu hero dan mengambil data
	if int (getData[index][1]) >= 270:
		saveData.append([getData[index][0], 'MARKSMAN'])  #mengecek berdasarkan movementSpeed
	elif int (getData[index][2]) >= 121:
		saveData.append([getData[index][0], 'ASSASSIN'])  #mengecek berdasarkan physicalAttack
	elif int (getData[index][3]) >= 25:
		saveData.append([getData[index][0], 'TANK'])      #mengecek berdasarkan armor
	if int (getData[index][4]) >= 2580:
		saveData.append([getData[index][0], 'FIGHTER'])   #mengecek hp
	if int (getData[index][5]) >= 500:
		saveData.append([getData[index][0], 'MAGE'])      #mengecek mana
	else: 
		saveData.append([getData[index][0], 'SUPPORT'])
		
with open('Prediction1.csv', 'w', newline='') as createcsv:   #mengcreate file csv berupa hasil prediksi
	new = csv.writer(buatcsv)
	for x in range(len(saveData)):
		new.writerow(saveData[x])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-2680d62cd351> in <module>()
#      34
#      35 with open('Prediction1.csv', 'w', newline='') as createcsv:   #mengcreate file csv berupa hasil prediksi
# ---> 36         new = csv.writer(buatcsv)
#      37         for x in range(len(saveData)):
#      38                 new.writerow(saveData[x])
#
# NameError: name 'buatcsv' is not defined

# %%
#Laily Dwi Anggaraini
#1301178513
#IF 41 GAB02

import csv #memasukkan file csv

getData = [] #inisialisasi awal variable
saveData = []

saveData.insert(0, ['name', 'role']) #menambahkan baris atau nama kolom

with open('test.csv') as filecsv: 
	line = csv.reader(filecsv)  #membuka file csv yang ada pada disk c 
	dataset = list(line)

	for x in range(53):  #perulangan sejumlah data yang akan dicari 
		for y in range (5):
			dataset[x][y] = dataset[x][y]
		getData.append(dataset[x])
	
for index in range(1, len(getData)): #perulangan untuk mengecek satu persatu hero dan mengambil data
	if int (getData[index][1]) >= 270:
		saveData.append([getData[index][0], 'MARKSMAN'])  #mengecek berdasarkan movementSpeed
	elif int (getData[index][2]) >= 121:
		saveData.append([getData[index][0], 'ASSASSIN'])  #mengecek berdasarkan physicalAttack
	elif int (getData[index][3]) >= 25:
		saveData.append([getData[index][0], 'TANK'])      #mengecek berdasarkan armor
	if int (getData[index][4]) >= 2580:
		saveData.append([getData[index][0], 'FIGHTER'])   #mengecek hp
	if int (getData[index][5]) >= 500:
		saveData.append([getData[index][0], 'MAGE'])      #mengecek mana
	else: 
		saveData.append([getData[index][0], 'SUPPORT'])
		
with open('Prediction1.csv', 'w', newline='') as buatcsv:   #mengcreate file csv berupa hasil prediksi
	new = csv.writer(buatcsv)
	for x in range(len(saveData)):
		new.writerow(saveData[x])

# %%
#Laily Dwi Anggaraini
#1301178513
#IF 41 GAB02

import csv #memasukkan file csv

getData = [] #inisialisasi awal variable
saveData = []

saveData.insert(0, ['name', 'role']) #menambahkan baris atau nama kolom

with open('test.csv') as filecsv: 
	line = csv.reader(filecsv)  #membuka file csv yang ada pada disk c 
	dataset = list(line)

	for x in range(53):  #perulangan sejumlah data yang akan dicari 
		for y in range (5):
			dataset[x][y] = dataset[x][y]
		getData.append(dataset[x])
	
for index in range(1, len(getData)): #perulangan untuk mengecek satu persatu hero dan mengambil data
	if int (getData[index][1]) >= 270:
		saveData.append([getData[index][0], 'MARKSMAN'])  #mengecek berdasarkan movementSpeed
	elif int (getData[index][2]) >= 121:
		saveData.append([getData[index][0], 'ASSASSIN'])  #mengecek berdasarkan physicalAttack
	elif int (getData[index][3]) >= 25:
		saveData.append([getData[index][0], 'TANK'])      #mengecek berdasarkan armor
	if int (getData[index][4]) >= 2580:
		saveData.append([getData[index][0], 'FIGHTER'])   #mengecek hp
	if int (getData[index][5]) >= 500:
		saveData.append([getData[index][0], 'MAGE'])      #mengecek mana
	else: 
		saveData.append([getData[index][0], 'SUPPORT'])
		
with open('Prediction.csv', 'w', newline='') as buatcsv:   #mengcreate file csv berupa hasil prediksi
	new = csv.writer(buatcsv)
	for x in range(len(saveData)):
		new.writerow(saveData[x])

# %%
#buat new pertama/nama kolom
saveData.insert(0, ['name', 'role'])

#buka file test.csv
with open('test.csv') as filecsv:
	line	= csv.reader(filecsv)
	dataset	= list(line)
	#forloop sebanyak 53
	for x in range(53):
		for y in range (5):
			dataset[x][y] = dataset[x][y]
		#tampung ke variable getData
		getData.append(dataset[x])

#forloop untuk getData
for index in range(1, len(getData)):
	#cek movementSpeed
	if int(getData[index][1]) >= 270:
		saveData.append([getData[index][0], 'MARKSMAN'])
	#cek physicalAttack
	elif int(getData[index][2]) >= 121:
		saveData.append([getData[index][0], 'ASSASSIN'])
	#cek armor
	elif int(getData[index][3]) >= 25:
		saveData.append([getData[index][0], 'TANK'])
	#cek hp
	elif int(getData[index][4]) >= 2580:
		saveData.append([getData[index][0], 'FIGHTER'])
	#cek mana
	elif int(getData[index][5]) >= 500:
		saveData.append([getData[index][0], 'MAGE'])
	else:
		saveData.append([getData[index][0], 'SUPPORT'])

#membuat file csv
with open('Prediction.csv', 'w', newline='') as buatcsv:
	new = csv.writer(buatcsv)
	for x in range(len(saveData)):
		new.writerow(saveData[x])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-1968c59637e9> in <module>()
#      16 for index in range(1, len(getData)):
#      17         #cek movementSpeed
# ---> 18         if int(getData[index][1]) >= 270:
#      19                 saveData.append([getData[index][0], 'MARKSMAN'])
#      20         #cek physicalAttack
#
# ValueError: invalid literal for int() with base 10: 'movementSpeed'

# %%
import csv

#inisialisasi variable
ambilData 	= []
saveData	= []

#buat new pertama/nama kolom
saveData.insert(0, ['name', 'role'])

#buka file test.csv
with open('test.csv') as filecsv:
	line	= csv.reader(filecsv)
	dataset	= list(line)
	#forloop sebanyak 53
	for x in range(53):
		for y in range (5):
			dataset[x][y] = dataset[x][y]
		#tampung ke variable ambilData
		ambilData.append(dataset[x])

#forloop untuk ambilData
for index in range(1, len(ambilData)):
	#cek movementSpeed
	if int(ambilData[index][1]) >= 270:
		saveData.append([ambilData[index][0], 'MARKSMAN'])
	#cek physicalAttack
	elif int(ambilData[index][2]) >= 121:
		saveData.append([ambilData[index][0], 'ASSASSIN'])
	#cek armor
	elif int(ambilData[index][3]) >= 25:
		saveData.append([ambilData[index][0], 'TANK'])
	#cek hp
	elif int(ambilData[index][4]) >= 2580:
		saveData.append([ambilData[index][0], 'FIGHTER'])
	#cek mana
	elif int(ambilData[index][5]) >= 500:
		saveData.append([ambilData[index][0], 'MAGE'])
	else:
		saveData.append([ambilData[index][0], 'SUPPORT'])

#membuat file csv
with open('Prediction.csv', 'w', newline='') as buatcsv:
	new = csv.writer(buatcsv)
	for x in range(len(saveData)):
		new.writerow(saveData[x])

# %%
import csv

#inisialisasi variable
getData 	= []
saveData	= []

#buat new pertama/nama kolom
saveData.insert(0, ['name', 'role'])

#buka file test.csv
with open('test.csv') as filecsv:
	line	= csv.reader(filecsv)
	dataset	= list(line)
	#forloop sebanyak 53
	for x in range(53):
		for y in range (5):
			dataset[x][y] = dataset[x][y]
		#tampung ke variable getData
		getData.append(dataset[x])

#forloop untuk getData
for index in range(1, len(getData)):
	#cek movementSpeed
	if int(getData[index][1]) >= 270:
		saveData.append([getData[index][0], 'MARKSMAN'])
	#cek physicalAttack
	elif int(getData[index][2]) >= 121:
		saveData.append([getData[index][0], 'ASSASSIN'])
	#cek armor
	elif int(getData[index][3]) >= 25:
		saveData.append([getData[index][0], 'TANK'])
	#cek hp
	elif int(getData[index][4]) >= 2580:
		saveData.append([getData[index][0], 'FIGHTER'])
	#cek mana
	elif int(getData[index][5]) >= 500:
		saveData.append([getData[index][0], 'MAGE'])
	else:
		saveData.append([getData[index][0], 'SUPPORT'])

#membuat file csv
with open('Prediction.csv', 'w', newline='') as buatcsv:
	new = csv.writer(buatcsv)
	for x in range(len(saveData)):
		new.writerow(saveData[x])

# %%
import csv

#inisialisasi variable
takeData 	= []
saveData	= []

#buat new pertama/nama kolom
saveData.insert(0, ['name', 'role'])

#buka file test.csv
with open('test.csv') as filecsv:
	line	= csv.reader(filecsv)
	dataset	= list(line)
	#forloop sebanyak 53
	for x in range(53):
		for y in range (5):
			dataset[x][y] = dataset[x][y]
		#tampung ke variable takeData
		takeData.append(dataset[x])

#forloop untuk takeData
for index in range(1, len(takeData)):
	#cek movementSpeed
	if int(takeData[index][1]) >= 270:
		saveData.append([takeData[index][0], 'MARKSMAN'])
	#cek physicalAttack
	elif int(takeData[index][2]) >= 121:
		saveData.append([takeData[index][0], 'ASSASSIN'])
	#cek armor
	elif int(takeData[index][3]) >= 25:
		saveData.append([takeData[index][0], 'TANK'])
	#cek hp
	elif int(takeData[index][4]) >= 2580:
		saveData.append([takeData[index][0], 'FIGHTER'])
	#cek mana
	elif int(takeData[index][5]) >= 500:
		saveData.append([takeData[index][0], 'MAGE'])
	else:
		saveData.append([takeData[index][0], 'SUPPORT'])

#membuat file csv
with open('Prediction.csv', 'w', newline='') as buatcsv:
	new = csv.writer(buatcsv)
	for x in range(len(saveData)):
		new.writerow(saveData[x])
